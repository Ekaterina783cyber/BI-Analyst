# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Загружаем данные

# %%
# Загрузите данные из файла insurance.csv в переменную df
df = pd.read_csv('Домашняя бухгалтерия (Ответы) - Траты.csv',sep=',')

# %%
df.head()
# Out:
#   Категория  Траты в позапрошлом месяце  Траты в прошлом месяце  \
# 0   Копилка                     12628.0                  6500.0
# 1  Продукты                       436.0                   215.0
# 2  Продукты                       520.0                   700.0
# 3  Продукты                       533.0                   338.0
# 4  Продукты                       664.0                   215.0
#
#    Траты в текущем месяце  Траты в следующем месяце
# 0                  7668.0                    8000.0
# 1                   799.0                     500.0
# 2                   153.0                     300.0
# 3                  1085.0                     600.0
# 4                   968.0                     200.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Категория                   34 non-null     object
#  1   Траты в позапрошлом месяце  34 non-null     float64
#  2   Траты в прошлом месяце      34 non-null     float64
#  3   Траты в текущем месяце      34 non-null     float64
#  4   Траты в следующем месяце    34 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 1.5+ KB

# %%
df.describe()
# Out:
#        Траты в позапрошлом месяце  Траты в прошлом месяце  \
# count                   34.000000               34.000000
# mean                  1046.000000              721.823529
# std                   2200.483625             1070.951757
# min                     99.000000              114.000000
# 25%                    300.000000              300.000000
# 50%                    510.000000              370.500000
# 75%                    976.250000              947.250000
# max                  12628.000000             6500.000000
#
#        Траты в текущем месяце  Траты в следующем месяце
# count               34.000000                 34.000000
# mean               736.235294                719.558824
# std               1290.157685               1320.746097
# min                 50.000000                 60.000000
# 25%                189.750000                300.000000
# 50%                300.000000                350.000000
# ...

# %%
##Разделить данные
from sklearn.model_selection import train_test_split

# %%
## Сформируйте признаки и целевую переменную
df.columns
# Out:
# Index(['Категория', 'Траты в позапрошлом месяце', 'Траты в прошлом месяце',
#        'Траты в текущем месяце', 'Траты в следующем месяце'],
#       dtype='object')

# %%
X = df[['Траты в позапрошлом месяце', 'Траты в прошлом месяце','Траты в текущем месяце']]
y = df['Траты в следующем месяце']

# %%
X
# Out:
#     Траты в позапрошлом месяце  Траты в прошлом месяце  Траты в текущем месяце
# 0                      12628.0                  6500.0                  7668.0
# 1                        436.0                   215.0                   799.0
# 2                        520.0                   700.0                   153.0
# 3                        533.0                   338.0                  1085.0
# 4                        664.0                   215.0                   968.0
# 5                        474.0                   949.0                   125.0
# 6                        542.0                   347.0                   109.0
# 7                        713.0                   394.0                    50.0
# 8                        320.0                   150.0                    50.0
# 9                        639.0                   809.0                    50.0
# 10                       306.0                   626.0                    50.0
# ...

# %%
y
# Out:
# 0     8000.0
# 1      500.0
# 2      300.0
# 3      600.0
# 4      200.0
# 5      200.0
# 6      200.0
# 7      200.0
# 8      150.0
# 9      350.0
# 10      60.0
# 11     520.0
# 12    1000.0
# 13    1000.0
# 14    1000.0
# 15    1000.0
# 16    1000.0
# 17    1000.0
# 18     300.0
# 19     300.0
# 20     300.0
# 21     300.0
# 22     300.0
# 23     300.0
# 24     300.0
# 25     300.0
# 26     300.0
# 27     685.0
# 28     800.0
# 29     600.0
# 30     350.0
# 31     450.0
# 32     850.0
# 33     750.0
# Name: Траты в следующем месяце, dtype: float64

# %%
#Разделить данные на часть для обучения и часть для проверки
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#     Траты в позапрошлом месяце  Траты в прошлом месяце  Траты в текущем месяце
# 19                       300.0                   300.0                   300.0
# 15                      1000.0                  1000.0                  1000.0
# 30                       250.0                  1020.0                  1093.0
# 6                        542.0                   347.0                   109.0
# 10                       306.0                   626.0                    50.0
# 21                       300.0                   300.0                   300.0
# 24                       300.0                   300.0                   300.0
# 13                      1000.0                  1000.0                  1000.0
# 26                       300.0                   300.0                   300.0
# 8                        320.0                   150.0                    50.0
# 14                      1000.0                  1000.0                  1000.0
# ...

# %%
X_test
# Out:
#     Траты в позапрошлом месяце  Траты в прошлом месяце  Траты в текущем месяце
# 16                      1000.0                  1000.0                  1000.0
# 33                       500.0                   173.0                   350.0
# 0                      12628.0                  6500.0                  7668.0
# 11                      4891.0                   200.0                    50.0
# 31                       300.0                   665.0                  1263.0
# 25                       300.0                   300.0                   300.0
# 12                      1000.0                  1000.0                  1000.0

# %%
y_train
# Out:
# 19     300.0
# 15    1000.0
# 30     350.0
# 6      200.0
# 10      60.0
# 21     300.0
# 24     300.0
# 13    1000.0
# 26     300.0
# 8      150.0
# 14    1000.0
# 29     600.0
# 1      500.0
# 5      200.0
# 2      300.0
# 9      350.0
# 7      200.0
# 3      600.0
# 32     850.0
# 20     300.0
# 17    1000.0
# 18     300.0
# 27     685.0
# 28     800.0
# 22     300.0
# 23     300.0
# 4      200.0
# Name: Траты в следующем месяце, dtype: float64

# %%
y_test
# Out:
# 16    1000.0
# 33     750.0
# 0     8000.0
# 11     520.0
# 31     450.0
# 25     300.0
# 12    1000.0
# Name: Траты в следующем месяце, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
# Создайте и обучите модель
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([0.37191148, 0.10199664, 0.39523126])

# %%
# Получите предсказание
lr.predict(X_test)
# Out:
# array([ 872.4923501 ,  345.28507137, 8393.46259307, 1862.5329166 ,
#         681.9312598 ,  264.09478553,  872.4923501 ])

# %%
# Оцените качество, при помощи метода mean_squared_error для тестовой выборки
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, lr.predict(X_test))
# Out:
# 315514.18757412693

# %%
mean_squared_error(y_train, lr.predict(X_train))
# Out:
# 28183.955597594286
